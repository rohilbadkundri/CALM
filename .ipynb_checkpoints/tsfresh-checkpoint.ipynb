# %%
import pandas as pd
from tsfresh.utilities.dataframe_functions import roll_time_series
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_relevant_features

# %%
cholera_case_crosstab = pd.read_csv(r'C:\Users\Rohil\Documents\iGEM\yemen\cholera_epi_data\yemen_cholera_case_data_differenced.csv', dayfirst = True)
conflict_crosstab = pd.read_csv('/Users/Rohil/Documents/iGEM/yemen/fatality_crosstab.csv')
cholera_death_crosstab = pd.read_csv(r'C:\Users\Rohil\Documents\iGEM\yemen\cholera_epi_data\yemen_cholera_death_data_differenced.csv', dayfirst = True)
max_rainfall_crosstab = pd.read_csv(r'C:\Users\Rohil\Documents\iGEM\yemen\rainfall\yemen_daily_max_rainfall_crosstab.csv', dayfirst = True)
mean_rainfall_crosstab = pd.read_csv(r'C:\Users\Rohil\Documents\iGEM\yemen\rainfall\yemen_daily_mean_rainfall_crosstab.csv', dayfirst = True)

# %%
gov_pop_area_data = pd.read_excel('/Users/Rohil/Documents/iGEM/yemen/gov_area_pop_data.xlsx')
gov_pop_area_data = gov_pop_area_data[gov_pop_area_data.iso != 'YE-HD']

# %%
norm_cholera_case_crosstab = cholera_case_crosstab
for index, row in gov_pop_area_data[['iso', 'population']].iterrows():
    norm_cholera_case_crosstab[row.iso] = (norm_cholera_case_crosstab[row.iso] * 10000) / row.population

# %%
norm_cholera_death_crosstab = cholera_death_crosstab
for index, row in gov_pop_area_data[['iso', 'population']].iterrows():
    norm_cholera_death_crosstab[row.iso] = (norm_cholera_death_crosstab[row.iso] * 10000) / row.population

# %%
norm_conflict_crosstab = conflict_crosstab
for index, row in gov_pop_area_data[['iso', 'population']].iterrows():
    norm_conflict_crosstab[row.iso] = (norm_conflict_crosstab[row.iso] * 10000) / row.population

# %%
cases_unstacked = norm_cholera_case_crosstab.set_index('date').unstack().reset_index()
cases_unstacked.columns = ['gov_iso', 'date', 'new_cases']

# %%
deaths_unstacked = norm_cholera_death_crosstab.set_index('date').unstack().reset_index()
deaths_unstacked.columns = ['gov_iso', 'date', 'new_deaths']

# %%
fatalities_unstacked = norm_conflict_crosstab.set_index('date').unstack().reset_index()
fatalities_unstacked.columns = ['gov_iso', 'date', 'fatalities']

# %%
mean_rainfall_unstacked = mean_rainfall_crosstab.set_index('date').unstack().reset_index()
mean_rainfall_unstacked.columns = ['gov_iso', 'date', 'mean_rainfall']

# %%
max_rainfall_unstacked = max_rainfall_crosstab.set_index('date').unstack().reset_index()
max_rainfall_unstacked.columns = ['gov_iso', 'date', 'max_rainfall']

# %%
cases_unstacked.date = pd.to_datetime(cases_unstacked.date, format = "%d-%m-%y")

# %%
deaths_unstacked.date = pd.to_datetime(deaths_unstacked.date, format = "%d-%m-%y")

# %%
mean_rainfall_unstacked.date = pd.to_datetime(mean_rainfall_unstacked.date, format = "%d-%m-%y")

# %%
max_rainfall_unstacked.date = pd.to_datetime(max_rainfall_unstacked.date, format = "%d-%m-%y")

# %%
fatalities_unstacked.date = pd.to_datetime(fatalities_unstacked.date, format = "%Y-%m-%d")

# %%
full_features = cases_unstacked.merge(deaths_unstacked, on =['date', 'gov_iso']).merge(fatalities_unstacked, on =['date', 'gov_iso'], how = 'left').merge(mean_rainfall_unstacked, on =['date', 'gov_iso'], how = 'left').merge(max_rainfall_unstacked, on =['date', 'gov_iso'], how = 'left')

# %%
y = pd.read_csv('/Users/Rohil/Documents/iGEM/yemen/cholera_epi_data/y_normalized_groupby_week_df.csv')

# %%
full_features = full_features.sort_values('date')

# %%
y = y.sort_values('date')

# %%
full_features.head()
# Out:
#      gov_iso       date  new_cases  new_deaths  fatalities  mean_rainfall  \
# 0      YE-AB 2017-05-23   0.901606    0.015179         0.0       0.000000
# 2176   YE-HU 2017-05-23   0.564781    0.004239         0.0      14.555986
# 3536   YE-MR 2017-05-23   0.000000    0.000000         0.0       0.000000
# 3808   YE-MW 2017-05-23   3.025834    0.030040         0.0      17.384593
# 4896   YE-SH 2017-05-23   0.000000    0.000000         0.0       0.000000
#
#       max_rainfall
# 0         0.000000
# 2176     27.310665
# 3536      0.000000
# 3808     22.224941
# 4896      0.000000

# %%
y.head()
# Out:
#      gov_iso        date  week_1_cases  week_2_cases  week_2_to_4_cases  \
# 0      YE-AB  2017-05-23      6.976066      7.594340          18.482427
# 1325   YE-DH  2017-05-23      7.294939      9.135369          28.028750
# 4240   YE-SA  2017-05-23     32.503467     37.056994          95.130921
# 4770   YE-SH  2017-05-23      0.046047      0.015349           0.598610
# 795    YE-BA  2017-05-23     17.116538     11.683058          23.629375
#
#       week_4_to_6_cases  week_6_to_8_cases
# 0             51.257999          65.009775
# 1325          44.058367          52.243076
# 4240          85.863835          65.281030
# 4770           2.118160           1.780482
# 795           29.137843          28.826720

# %%
y.date = pd.to_datetime(y.date, format = '%Y-%m-%d')

# %%
full_data = y.merge(full_features, on = ['gov_iso', 'date'], how = 'left')

# %%
full_data['days_from'] = full_data.date - y.iloc[0].date

# %%
full_data['days_from'] = full_data.days_from.dt.days

# %%
full_data.to_csv('/Users/Rohil/Documents/iGEM/yemen/tsfresh_input.csv', index = False)

# %%
full_data[full_features.columns].head()
# Out:
#   gov_iso       date  new_cases  new_deaths  fatalities  mean_rainfall  \
# 0   YE-AB 2017-05-23   0.901606    0.015179         0.0       0.000000
# 1   YE-DH 2017-05-23   1.048868    0.009428         0.0       0.454375
# 2   YE-SA 2017-05-23   5.665804    0.005107         0.0       0.000000
# 3   YE-SH 2017-05-23   0.000000    0.000000         0.0       0.000000
# 4   YE-BA 2017-05-23   2.484196    0.004787         0.0       0.124548
#
#    max_rainfall
# 0      0.000000
# 1      2.987849
# 2      0.000000
# 3      0.000000
# 4      1.058524

# %%
new_cases_timeseries = full_data.dropna()[['days_from', 'gov_iso', 'new_cases', 'new_deaths']]

# %%
new_cases_timeseries.head()
# Out:
#    days_from gov_iso  new_cases  new_deaths
# 0          0   YE-AB   0.901606    0.015179
# 1          0   YE-DH   1.048868    0.009428
# 2          0   YE-SA   5.665804    0.005107
# 3          0   YE-SH   0.000000    0.000000
# 4          0   YE-BA   2.484196    0.004787

# %%
rolled_new_cases_timeseries = pd.DataFrame(columns=new_cases_timeseries.columns)
for gov in new_cases_timeseries.gov_iso.unique():
    gov_timeseries = new_cases_timeseries[new_cases_timeseries.gov_iso == gov]
    rolled_gov_timeseries = roll_time_series(gov_timeseries, column_id = 'gov_iso', column_sort = 'days_from', column_kind = None, rolling_direction = 1, max_timeshift = 28)
    rolled_gov_timeseries['id_col'] = rolled_gov_timeseries.gov_iso.map(str) + '_' + gov
    rolled_new_cases_timeseries = rolled_new_cases_timeseries.append(rolled_gov_timeseries)
# Out:
# C:\Users\Rohil\Anaconda3\lib\site-packages\tsfresh\utilities\dataframe_functions.py:388: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   differences = df.groupby(grouper)[column_sort].apply(
# C:\Users\Rohil\Anaconda3\lib\site-packages\tsfresh\utilities\dataframe_functions.py:400: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   grouped_data = df.groupby(grouper)
# C:\Users\Rohil\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
rolled_new_cases_timeseries.id_col = rolled_new_cases_timeseries.id_col.str.split('_').map(tuple)

# %%
rolled_new_cases_timeseries.drop('gov_iso', axis=1, inplace = True)

# %%
extract_test = extract_features(rolled_new_cases_timeseries, column_id = 'id_col', column_sort = 'days_from')
# Out:
# Feature Extraction:   0%|                                                                       | 0/20 [00:00<?, ?it/s]
#
#
# Feature Extraction:   5%|███▏                                                           | 1/20 [01:25<27:12, 85.94s/it]
#
#
# Feature Extraction:  10%|██████▎                                                        | 2/20 [01:35<14:19, 47.75s/it]
#
#
# Feature Extraction:  15%|█████████▍                                                     | 3/20 [01:38<09:17, 32.77s/it]
#
#
# Feature Extraction:  20%|████████████▌                                                  | 4/20 [01:38<06:33, 24.58s/it]
#
#
# Feature Extraction:  25%|███████████████▊                                               | 5/20 [03:02<09:07, 36.52s/it]
#
#
# Feature Extraction:  30%|██████████████████▉                                            | 6/20 [03:12<07:28, 32.03s/it]
#
#
# ...

# %%
index_reset = extract_test.reset_index().id.apply(pd.Series)

# %%
extract_test.reset_index(drop = True, inplace=True)

# %%
index_reset.head()
# Out:
#    0      1
# 0  0  YE-AB
# 1  0  YE-AD
# 2  0  YE-AM
# 3  0  YE-BA
# 4  0  YE-DA

# %%
extract_test['days_from'] = index_reset[0]
extract_test['gov_iso'] = index_reset[1]

# %%
all_feature_list = extract_test.drop(columns = ['days_from', 'gov_iso'], axis=1).columns

# %%
extract_test.days_from = extract_test.days_from.map(int)

# %%
full_extract = extract_test.merge(full_data.dropna()[['days_from', 'gov_iso', 'week_4_to_6_cases']], on = ['days_from', 'gov_iso'])

# %%
features_filtered = select_features(impute(full_extract[all_feature_list]), full_extract.week_4_to_6_cases)
# Out:
# WARNING:tsfresh.utilities.dataframe_functions:The columns ['new_cases__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"'
#  'new_cases__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"'
#  'new_cases__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"'
#  'new_cases__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"'
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"'
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"'
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"'
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"'
#  'new_cases__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"'
#  'new_cases__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"'
#  'new_cases__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope"'
#  'new_cases__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"'
# ...

# %%
y = full_extract[['days_from', 'gov_iso', 'week_4_to_6_cases']].merge(full_data[['days_from', 'date']].drop_duplicates(), how = 'left').drop('days_from', axis=1)

# %%
features_filtered = pd.concat([features_filtered, y[['date', 'gov_iso']]], axis=1).sort_values('date')

# %%
features_filtered
# Out:
#       new_cases__abs_energy  new_deaths__agg_autocorrelation__f_agg_"var"  \
# 0                  0.812894                                      0.000000
# 20                 0.495515                                      0.000000
# 19                 1.892387                                      0.000000
# 18                 0.000000                                      0.000000
# 17                 0.000000                                      0.000000
# 16                32.101339                                      0.000000
# 14                 9.155673                                      0.000000
# 13                 0.000000                                      0.000000
# 12                 0.051021                                      0.000000
# 11                 0.119345                                      0.000000
# 15                 0.711952                                      0.000000
# 9                  0.166941                                      0.000000
# ...

# %%
y = y.sort_values('date')

# %%
X = features_filtered[features_filtered.date > '2017-06-19'].sort_values('date')

# %%
y_fin = y[y.date > '2017-06-19'].sort_values('date')

# %%
import xgboost
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
def scale_features(scaler, X, categorical_cols):
        
    X_scaled = pd.DataFrame(data=scaler.transform(X), columns = X.columns)
        
    return (X_scaled)

# %%
def train_base_selection_model(X, y, param_grid, split_date, categorical_cols):
    
    # some of the ending values are undefined purposely, as there isnt't enough data to get cholera cases for x weeks
    y = y.dropna()
    X = X.loc[y.index]
    
    print ('X shape:')
    
    X_train, X_test = X[(X.date<split_date)].drop('date', axis=1), X[(X.date>=split_date)].drop('date', axis=1)
    y_train, y_test = y[(y.date<split_date)].drop('date', axis=1), y[(y.date>=split_date)].drop('date', axis=1)
    
    scaler = StandardScaler()
    scaler.fit(X_train)
    
    X_train, X_test = scale_features(scaler, X_train, categorical_cols), scale_features(scaler, X_test, categorical_cols)
    
    xgb = xgboost.XGBRegressor()
    
    grid_search = GridSearchCV(xgb,
                        param_grid = param_grid,
                        cv = TimeSeriesSplit(n_splits=2).split(X_train),
                        n_jobs = -1,
                        scoring = 'explained_variance',
                        verbose=True)
    
    grid_search.fit(X_train, y_train)
    
    y_pred = grid_search.predict(X_test)
    score = explained_variance_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    
    print('w/ all features... explained variance: %s, mean abs error: %s' % (score, mae))

    
    return(grid_search.best_estimator_, grid_search.best_params_)

# %%
quick_search_params = {'colsample_bytree': [0.4, 0.6],
 'learning_rate': [0.01],
 'max_depth': [10],
 'min_child_weight': [32, 45],
 'n_estimators': [150],
 'nthread': [4],
 'objective': ['reg:linear'],
 'silent': [1],
 'subsample':[0.4, 0.6]}

# %%
week4_6_xgb, week4_6_params = train_base_selection_model(X.drop('gov_iso', axis=1), y_fin.drop('gov_iso', axis=1), quick_search_params, '2017-9-25', categorical_cols = None)
# Out:
# X shape:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   15.4s finished
# w/ all features... explained variance: 0.5477414236966698, mean abs error: 6.03175763784966

# %%
xgboost.plot_importance(week4_6_xgb, max_num_features=50)
plt.tight_layout()

# %%
extract_test.shape
# Out:
# (4536, 1588)

# %%
[col for col in full_extract.columns if 'mean' in col]
# Out:
# ['new_cases__agg_autocorrelation__f_agg_"mean"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#  'new_cases__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
# ...

# %%
week4_6_params
# Out:
# {'colsample_bytree': 0.4,
#  'learning_rate': 0.01,
#  'max_depth': 10,
#  'min_child_weight': 32,
#  'n_estimators': 150,
#  'nthread': 4,
#  'objective': 'reg:linear',
#  'silent': 1,
#  'subsample': 0.6}

# %%
y.dropna().shape
# Out:
# (4536, 7)

# %%
features_filtered = select_features(extract_test.reset_index(drop = True), full_data.dropna().week_4_to_6_cases)
# Out:
# WARNING:tsfresh.feature_selection.relevance:Infered regression as machine learning task
