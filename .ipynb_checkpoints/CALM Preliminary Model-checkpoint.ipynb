# %%
#
# Built by Rohil Badkundri on 9th April 2018
# Lambert iGEM One Day Georgia Team
#

# %%
#make imports
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load some example data
angola_data = pd.read_excel('/Users/Rohil/Documents/iGEM/Angola_data_CALM_preliminary_NO_OUTLIERS.xlsx')

# %%
data = angola_data.drop(['Country Name', 'Month', 'Year'], axis=1)

# %%
data.columns
# Out:
# Index(['Suspected Cholera Cases', 'Precipitation ', 'Population in Thousands',
#        '% Population Urban', 'National At Least Basic',
#        'National Limited (more than 30 mins)', 'Unimproved', 'Surface Water',
#        'Rural At Least Basic', 'Rural Limited (more than 30 mins)',
#        'Unimproved.1', 'Surface Water.1', 'Urban At Least Basic',
#        'Urban Limited (more than 30 mins)', 'Unimproved.2', 'Surface Water.2',
#        'National Proportion of Population Using Improved Water Supplies; Accessible on Premises',
#        'National Proportion of Population Using Improved Water Supplies; Available when needed',
#        'National Proportion of Population Using Improved Water Supplies; Piped',
#        'National Proportion of Population Using Improved Water Supplies; Non-piped',
#        'Rural Proportion of Population Using Improved Water Supplies;Accessible on premises',
#        'Rural Proportion of Population Using Improved Water Supplies; available when needed',
# ...

# %%
plt.scatter(standard_scaled_df['Precipitation '], standard_scaled_df['Suspected Cholera Cases'])

# %%
standard_scaler = preprocessing.StandardScaler()
standard_scaled_df = standard_scaler.fit_transform(data)
standard_scaled_df = pd.DataFrame(standard_scaled_df, columns = data.columns)

# %%
robust_scaler = preprocessing.RobustScaler()
robust_scaled_df = robust_scaler.fit_transform(data)
robust_scaled_df = pd.DataFrame(robust_scaled_df, columns = data.columns)

# %%
standard_scaled_df
# Out:
#     Suspected Cholera Cases  Precipitation   Population in Thousands  \
# 0                 -0.640784        1.059106                -1.509969
# 1                 -0.513318        1.247384                -1.509969
# 2                  0.474544        1.299593                -1.509969
# 3                  1.196852       -1.216909                -1.509969
# 4                  0.293967       -1.144685                -1.509969
# 5                  0.223153       -0.950165                -1.509969
# 6                  0.761343       -0.074224                -1.509969
# 7                  3.615168        1.450781                -1.509969
# 8                  3.397059        1.070674                -1.509969
# 9                  2.439647        1.031338                -0.811853
# 10                 2.195337        0.550961                -0.811853
# 11                 1.667769        1.257288                -0.811853
# 12                 1.543843        0.185474                -0.811853
# ...

# %%
X_train = np.array(standard_scaled_df.iloc[0:48].drop(columns = ['Suspected Cholera Cases']))
Y_train = np.array(standard_scaled_df.iloc[0:48]['Suspected Cholera Cases'])
X_test = np.array(standard_scaled_df.iloc[48:60].drop(columns = ['Suspected Cholera Cases']))
Y_test = np.array(standard_scaled_df.iloc[48:60]['Suspected Cholera Cases'])

# %%
X = np.array(standard_scaled_df.drop(columns = ['Suspected Cholera Cases']))
Y = np.array(standard_scaled_df['Suspected Cholera Cases'])

# %%
#X_train = np.array(standard_scaled_df.iloc[0:48]['Precipitation '])
#Y_train = np.array(standard_scaled_df.iloc[0:48]['Suspected Cholera Cases'])
#X_test = np.array(standard_scaled_df.iloc[48:60]['Precipitation '])
#Y_test = np.array(standard_scaled_df.iloc[48:60]['Suspected Cholera Cases'])

# %%
Y_train.shape
# Out:
# (48,)

# %%
X_test.shape
# Out:
# (9, 50)

# %%
Y_test.shape
# Out:
# (9,)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.score(X_test, Y_test)
# Out:
# -34.06009577477703

# %%
regr.score(X_train, Y_train)
# Out:
# 0.34012715704040264

# %%
Y_pred_false = regr.predict(X_train)

# %%
regr.predict(X)
# Out:
# array([ 1.08853423,  1.15103423,  1.15103423,  0.52603423,  0.58853423,
#         0.65103423,  0.83853423,  1.15103423,  1.08853423,  0.70962798,
#         0.58462798,  0.74087798,  0.49087798,  0.24087798,  0.17837798,
#         0.17837798,  0.17837798,  0.24087798,  0.42837798,  0.67837798,
#         0.74087798,  0.08194243,  0.05069243,  0.13662993, -0.12508882,
#        -0.39071382, -0.45712007, -0.45712007, -0.44930757, -0.39462007,
#        -0.18368257, -0.01962007,  0.08975493, -0.19271577, -0.19271577,
#        -0.13021577, -0.31771577, -0.66146577, -0.72396577, -0.72396577,
#        -0.69271577, -0.66146577, -0.47396577, -0.28646577, -0.19271577,
#        -0.35677827, -0.41927827, -0.29427827, -0.48177827, -0.79427827,
#        -0.85677827, -0.85677827, -0.79427827, -0.79427827, -0.66927827,
#        -0.29427827, -0.37191499])

# %%
Y
# Out:
# array([-0.64078434, -0.51331823,  0.47454418,  1.19685217,  0.29396718,
#         0.22315267,  0.76134294,  3.61516766,  3.39705897,  2.43964681,
#         2.19533675,  1.66776866,  1.54384327,  0.52553062, -0.37027292,
#        -0.61599927, -0.57917572, -0.37522993, -0.45737476, -0.4956146 ,
#        -0.37735437,  0.1325101 ,  0.03691051,  0.72876827,  0.89164164,
#         0.94546066, -0.3292005 , -0.4956146 , -0.58059201, -0.62166443,
#        -0.58059201, -0.41417791, -0.214481  , -0.44250372, -0.56996983,
#        -0.61245854, -0.54518476, -0.53810331, -0.46374807, -0.60537709,
#        -0.35398558, -0.61599927, -0.53527072, -0.61599927, -0.61599927,
#        -0.56996983, -0.54518476, -0.61953999, -0.37168921, -0.43188154,
#        -0.63724362, -0.63724362, -0.65494725, -0.65494725, -0.51331823,
#        -0.6181237 , -0.63936805])

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [-8.25786663e-01 -7.67934805e+02  7.16849608e+04  1.82802504e+04
#   1.42826057e+03  1.57244641e+04 -3.54329751e+04  4.01638447e+01
#   2.25157024e+01 -8.11475652e+02  7.48796107e+02  5.66283136e+02
#   1.71845547e+02 -1.91071658e+03  1.17258791e+03  8.13002587e+04
#   2.15437529e+03  1.05002739e+05 -8.52942283e+04 -1.99692682e+03
#   3.96258404e+01  6.07017944e+02 -5.44338397e+02 -6.13435597e+04
#   2.96503263e+02 -3.05271070e+03  3.79083938e+03  3.00828768e+04
#   2.25711214e+04 -1.43137263e+03 -5.12226255e+04  6.21558370e-08
#  -1.85897127e+03 -4.76562370e+02  9.32088031e+02  1.40344561e+03
#   0.00000000e+00 -1.99032175e+03 -8.64006629e+02  7.08094037e+02
#   2.14623435e+03 -7.45515654e+04  1.00983607e+05  3.65083483e+03
#   8.73459813e+02 -2.74393707e+03  1.15059870e+01  3.94616442e+03
#  -6.08177483e+03  1.45288656e+02]

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test,Y_pred))
# Out:
# Mean squared error: 108235848331560861696.00

# %%
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test, Y_pred))
# Out:
# Variance score: -15763920184326345457664.00

# %%
Y_pred
# Out:
# array([1.04036459e+10, 1.04036459e+10, 1.04036459e+10, 1.04036459e+10,
#        1.04036459e+10, 1.04036459e+10, 1.04036459e+10, 1.04036459e+10,
#        1.04036459e+10, 1.04036459e+10, 1.04036459e+10, 1.04036459e+10])

# %%
Y_test
# Out:
# array([-0.1117521 , -0.08867645, -0.15790341,  0.07285314,  0.01681226,
#        -0.17438602, -0.17438602, -0.19086863, -0.19086863, -0.05900775,
#        -0.1565848 , -0.17636394])

# %% [markdown]
# # Let's next build a model with just numpy

# %%
standard_scaled_df
# Out:
#     Suspected Cholera Cases  Precipitation   Population in Thousands  \
# 0                 -0.440134        1.098712                -1.394400
# 1                 -0.391576        1.287923                -1.394400
# 2                 -0.015255        1.340390                -1.394400
# 3                  5.230310        0.187140                -1.394400
# 4                  4.474970       -0.950996                -1.394400
# 5                  1.468448       -1.194652                -1.394400
# 6                  0.259904       -1.188577                -1.394400
# 7                 -0.084045       -1.115996                -1.394400
# 8                 -0.111021       -0.920511                -1.394400
# 9                  0.093999       -0.040232                -1.394400
# 10                 1.181149        1.492327                -1.394400
# 11                 1.098062        1.110338                -1.394400
# 12                 0.733340        1.070806                -0.715785
# ...

# %%
X_train = np.array(standard_scaled_df.iloc[0:48].drop(columns = ['Suspected Cholera Cases']))
Y_train = np.array(standard_scaled_df.iloc[0:48]['Suspected Cholera Cases'])
X_test = np.array(standard_scaled_df.iloc[48:60].drop(columns = ['Suspected Cholera Cases']))
Y_test = np.array(standard_scaled_df.iloc[48:60]['Suspected Cholera Cases'])

# %%
from sklearn.svm import NuSVR

# %%
clf = NuSVR(C=1.0, nu=0.1)

# %%
clf.fit(X_train, Y_train)
# Out:
# NuSVR(C=1.0, cache_size=200, coef0=0.0, degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, nu=0.1, shrinking=True, tol=0.001, verbose=False)

# %%
clf.score(X_test, Y_test)
# Out:
# -215.62915148213557

# %%
clf.score(X_train, Y_train)
# Out:
# -0.5810193166960689

# %%
plt.scatter(data.index, data['Suspected Cholera Cases'])

# %%
# Out:
# RangeIndex(start=0, stop=60, step=1)
